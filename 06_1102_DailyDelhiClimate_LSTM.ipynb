# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/Users/minjeong/Downloads/DailyDelhiClimateTrain.csv')
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace= True)

# %%
plt.figure(figsize=(15, 6))
df['meantemp'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Mean Temperature")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['humidity'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Humidity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['wind_speed'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Wind Spead")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['meanpressure'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Mean Pressure")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
n_cols = 1
dataset = df["meantemp"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1462, 1)

# %%
# Normalizing Data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
# Splitting Data
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (1096, 1)

# %%
# Creating training set
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps, len(scaled_data)):
    x_train.append(scaled_data[i-time_steps:i, :n_cols])
    y_train.append(scaled_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.12227074],
#        [0.04279476],
#        [0.0356623 ],
#        [0.08151383],
#        [0.        ],
#        [0.03056769],
#        [0.03056769],
#        [0.08733624],
#        [0.24454148],
#        [0.15283843],
#        [0.29694323],
#        [0.24454148],
#        [0.30058224],
#        [0.20887918],
#        [0.26637555],
#        [0.23944687],
#        [0.3209607 ],
#        [0.23944687],
#        [0.19868996],
#        [0.16157205],
#        [0.15895197],
#        [0.1069869 ],
#        [0.24454148],
#        [0.23944687],
#        [0.19104803],
#        [0.20378457],
#        [0.20960699],
#        [0.27001456],
#        [0.24836245],
#        [0.26637555],
#        [0.31179039],
#        [0.30567686],
#        [0.31441048],
#        [0.36681223],
#        [0.34934498],
#        [0.32478166],
#        [0.32605531],
#        [0.29344978],
#        [0.24454148],
#        [0.28820961],
#        [0.28275109],
#        [0.3018559 ],
#        [0.2852984 ],
#        [0.31441048],
#        [0.34643377],
#        [0.40247453],
#        [0.25764192],
#        [0.23435226],
#        [0.29344978],
#        [0.30131004],
#        [0.3580786 ],
#        [0.4279476 ],
#        [0.44323144],
#        [0.34934498],
#        [0.33187773],
#        [0.33242358],
#        [0.36244541],
#        [0.45240175],
#        [0.41048035],
#        [0.34643377]])]
# y_train: [array([0.39737991])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((1402, 60, 1), (1402, 1))

# %% [markdown]
# # LSTM Model

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42465 (165.88 KB)
# Trainable params: 42465 (165.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 2s 19ms/step - loss: 0.0366 - mean_absolute_error: 0.1360
# Epoch 2/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0064 - mean_absolute_error: 0.0638
# Epoch 3/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0054 - mean_absolute_error: 0.0581
# Epoch 4/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0052 - mean_absolute_error: 0.0572
# Epoch 5/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.0547
# Epoch 6/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0049 - mean_absolute_error: 0.0546
# Epoch 7/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0045 - mean_absolute_error: 0.0527
# Epoch 8/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0046 - mean_absolute_error: 0.0534
# Epoch 9/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0046 - mean_absolute_error: 0.0530
# Epoch 10/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0045 - mean_absolute_error: 0.0527
# Epoch 11/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0043 - mean_absolute_error: 0.0515
# Epoch 12/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0046 - mean_absolute_error: 0.0531
# Epoch 13/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0041 - mean_absolute_error: 0.0499
# Epoch 14/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0040 - mean_absolute_error: 0.0495
# Epoch 15/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0040 - mean_absolute_error: 0.0494
# Epoch 16/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0038 - mean_absolute_error: 0.0481
# Epoch 17/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0040 - mean_absolute_error: 0.0495
# Epoch 18/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0039 - mean_absolute_error: 0.0486
# Epoch 19/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0037 - mean_absolute_error: 0.0475
# Epoch 20/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0036 - mean_absolute_error: 0.0464
# Epoch 21/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0034 - mean_absolute_error: 0.0453
# Epoch 22/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0035 - mean_absolute_error: 0.0463
# Epoch 23/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0031 - mean_absolute_error: 0.0436
# Epoch 24/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0033 - mean_absolute_error: 0.0446
# Epoch 25/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0030 - mean_absolute_error: 0.0422
# Epoch 26/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0028 - mean_absolute_error: 0.0411
# Epoch 27/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0028 - mean_absolute_error: 0.0414
# Epoch 28/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0029 - mean_absolute_error: 0.0421
# Epoch 29/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0391
# Epoch 30/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0028 - mean_absolute_error: 0.0407
# Epoch 31/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0406
# Epoch 32/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0398
# Epoch 33/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0030 - mean_absolute_error: 0.0425
# Epoch 34/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 35/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0392
# Epoch 36/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 37/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 38/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0383
# Epoch 39/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0380
# Epoch 40/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 41/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0396
# Epoch 42/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 43/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0402
# Epoch 44/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0383
# Epoch 45/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0390
# Epoch 46/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0389
# Epoch 47/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 48/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 49/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 50/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 51/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 52/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0396
# Epoch 53/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0397
# Epoch 54/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 55/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0378
# Epoch 56/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 57/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0378
# Epoch 58/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0384
# Epoch 59/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 60/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0380
# Epoch 61/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0395
# Epoch 62/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 63/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0388
# Epoch 64/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0378
# Epoch 65/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 66/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 67/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0397
# Epoch 68/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 69/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0392
# Epoch 70/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0376
# Epoch 71/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 72/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 73/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0385
# Epoch 74/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 75/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 76/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0372
# Epoch 77/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0404
# Epoch 78/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0386
# Epoch 79/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0382
# Epoch 80/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0378
# Epoch 81/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0394
# Epoch 82/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0368
# Epoch 83/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 84/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 85/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0371
# Epoch 86/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0401
# Epoch 87/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 88/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0401
# Epoch 89/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0381
# Epoch 90/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 91/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0396
# Epoch 92/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 93/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0375
# Epoch 94/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 95/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0375
# Epoch 96/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 97/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0369
# Epoch 98/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0024 - mean_absolute_error: 0.0377
# Epoch 99/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0392
# Epoch 100/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0025 - mean_absolute_error: 0.0385

# %% [markdown]
# # Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Prediction

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
# Get Prediction
predictions = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 5ms/step

# %%
predictions.shape
# Out:
# (366, 1)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (366, 1)

# %%
# Root mean square error
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.64

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions    Actuals
# 0      14.495548  14.000000
# 1      14.010906  14.375000
# 2      14.111579  15.750000
# 3      15.027801  15.833333
# 4      15.376887  17.375000
# ..           ...        ...
# 361    16.862841  17.217391
# 362    17.096115  15.238095
# 363    15.822437  14.095238
# 364    14.699832  15.052632
# 365    14.988672  10.000000
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %%
# Visualize Predictions with The Data
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Temperature Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Temperature', fontsize= 18)
plt.plot(train['meantemp'], linewidth= 3)
plt.plot(test['meantemp'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
