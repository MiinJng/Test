# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/Users/minjeong/Downloads/DailyDelhiClimateTrain.csv')
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace= True)

# %% [markdown]
# # Data Preprocessing

# %%
n_cols = 1
dataset = df["meantemp"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1462, 1)

# %%
# Normalizing Data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
# Splitting Data
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 1096 Test Size : 366

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (1096, 1)

# %%
# Creating training set
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps, len(scaled_data)):
    x_train.append(scaled_data[i-time_steps:i, :n_cols])
    y_train.append(scaled_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.12227074],
#        [0.04279476],
#        [0.0356623 ],
#        [0.08151383],
#        [0.        ],
#        [0.03056769],
#        [0.03056769],
#        [0.08733624],
#        [0.24454148],
#        [0.15283843],
#        [0.29694323],
#        [0.24454148],
#        [0.30058224],
#        [0.20887918],
#        [0.26637555],
#        [0.23944687],
#        [0.3209607 ],
#        [0.23944687],
#        [0.19868996],
#        [0.16157205],
#        [0.15895197],
#        [0.1069869 ],
#        [0.24454148],
#        [0.23944687],
#        [0.19104803],
#        [0.20378457],
#        [0.20960699],
#        [0.27001456],
#        [0.24836245],
#        [0.26637555],
#        [0.31179039],
#        [0.30567686],
#        [0.31441048],
#        [0.36681223],
#        [0.34934498],
#        [0.32478166],
#        [0.32605531],
#        [0.29344978],
#        [0.24454148],
#        [0.28820961],
#        [0.28275109],
#        [0.3018559 ],
#        [0.2852984 ],
#        [0.31441048],
#        [0.34643377],
#        [0.40247453],
#        [0.25764192],
#        [0.23435226],
#        [0.29344978],
#        [0.30131004],
#        [0.3580786 ],
#        [0.4279476 ],
#        [0.44323144],
#        [0.34934498],
#        [0.33187773],
#        [0.33242358],
#        [0.36244541],
#        [0.45240175],
#        [0.41048035],
#        [0.34643377]])]
# y_train: [array([0.39737991])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((1402, 60, 1), (1402, 1))

# %% [markdown]
# # CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout

model = Sequential([
    SimpleRNN(20, activation='relu', input_shape=(x_train.shape[1:]), return_sequences=True),
    Dropout(0.5),
    SimpleRNN(20, activation='relu'),
    Dropout(0.3),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 60, 20)            440
#
#  dropout_2 (Dropout)         (None, 60, 20)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 20)                820
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1281 (5.00 KB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 1s 5ms/step - loss: 0.1862 - mean_absolute_error: 0.3274
# Epoch 2/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0727 - mean_absolute_error: 0.2088
# Epoch 3/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0596 - mean_absolute_error: 0.1898
# Epoch 4/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0492 - mean_absolute_error: 0.1696
# Epoch 5/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0416 - mean_absolute_error: 0.1530
# Epoch 6/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0397 - mean_absolute_error: 0.1485
# Epoch 7/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0374 - mean_absolute_error: 0.1467
# Epoch 8/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0309 - mean_absolute_error: 0.1341
# Epoch 9/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0272 - mean_absolute_error: 0.1273
# Epoch 10/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0250 - mean_absolute_error: 0.1195
# Epoch 11/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0236 - mean_absolute_error: 0.1165
# Epoch 12/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0226 - mean_absolute_error: 0.1139
# Epoch 13/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0202 - mean_absolute_error: 0.1090
# Epoch 14/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0207 - mean_absolute_error: 0.1090
# Epoch 15/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0180 - mean_absolute_error: 0.1026
# Epoch 16/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0171 - mean_absolute_error: 0.1008
# Epoch 17/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0167 - mean_absolute_error: 0.0993
# Epoch 18/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0160 - mean_absolute_error: 0.0963
# Epoch 19/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0160 - mean_absolute_error: 0.0972
# Epoch 20/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0149 - mean_absolute_error: 0.0923
# Epoch 21/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0140 - mean_absolute_error: 0.0920
# Epoch 22/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0143 - mean_absolute_error: 0.0908
# Epoch 23/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0129 - mean_absolute_error: 0.0873
# Epoch 24/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0124 - mean_absolute_error: 0.0868
# Epoch 25/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0868
# Epoch 26/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0113 - mean_absolute_error: 0.0829
# Epoch 27/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0809
# Epoch 28/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0801
# Epoch 29/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0792
# Epoch 30/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0767
# Epoch 31/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0793
# Epoch 32/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0753
# Epoch 33/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0771
# Epoch 34/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0770
# Epoch 35/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0743
# Epoch 36/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0754
# Epoch 37/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0755
# Epoch 38/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0746
# Epoch 39/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0726
# Epoch 40/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0733
# Epoch 41/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0728
# Epoch 42/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0734
# Epoch 43/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0085 - mean_absolute_error: 0.0708
# Epoch 44/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0720
# Epoch 45/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0691
# Epoch 46/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0692
# Epoch 47/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0695
# Epoch 48/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0692
# Epoch 49/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0708
# Epoch 50/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0695
# Epoch 51/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0665
# Epoch 52/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0701
# Epoch 53/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0083 - mean_absolute_error: 0.0704
# Epoch 54/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0081 - mean_absolute_error: 0.0702
# Epoch 55/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0078 - mean_absolute_error: 0.0684
# Epoch 56/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0696
# Epoch 57/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0679
# Epoch 58/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0651
# Epoch 59/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0685
# Epoch 60/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0685
# Epoch 61/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_absolute_error: 0.0666
# Epoch 62/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_absolute_error: 0.0668
# Epoch 63/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0072 - mean_absolute_error: 0.0659
# Epoch 64/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0073 - mean_absolute_error: 0.0667
# Epoch 65/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_absolute_error: 0.0654
# Epoch 66/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0659
# Epoch 67/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_absolute_error: 0.0657
# Epoch 68/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0646
# Epoch 69/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0660
# Epoch 70/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0648
# Epoch 71/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0632
# Epoch 72/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0068 - mean_absolute_error: 0.0641
# Epoch 73/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0654
# Epoch 74/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0655
# Epoch 75/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0648
# Epoch 76/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0643
# Epoch 77/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0630
# Epoch 78/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0069 - mean_absolute_error: 0.0649
# Epoch 79/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0621
# Epoch 80/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0629
# Epoch 81/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0652
# Epoch 82/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0641
# Epoch 83/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0618
# Epoch 84/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0608
# Epoch 85/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0613
# Epoch 86/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0629
# Epoch 87/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0620
# Epoch 88/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0609
# Epoch 89/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0616
# Epoch 90/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0615
# Epoch 91/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0599
# Epoch 92/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0599
# Epoch 93/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0612
# Epoch 94/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0066 - mean_absolute_error: 0.0626
# Epoch 95/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0613
# Epoch 96/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0613
# Epoch 97/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0633
# Epoch 98/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0603
# Epoch 99/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0063 - mean_absolute_error: 0.0607
# Epoch 100/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0059 - mean_absolute_error: 0.0601

# %% [markdown]
# # Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Prediction

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
# Get Prediction
predictions = model.predict(x_test)
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
predictions.shape
# Out:
# (366, 1)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (366, 1)

# %%
# Root mean square error
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 0.56

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#      Predictions    Actuals
# 0      18.733841  14.000000
# 1      18.507477  14.375000
# 2      18.389050  15.750000
# 3      18.671139  15.833333
# 4      18.946169  17.375000
# ..           ...        ...
# 361    19.598186  17.217391
# 362    19.811342  15.238095
# 363    19.484549  14.095238
# 364    18.750198  15.052632
# 365    18.701990  10.000000
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %%
# Visualize Predictions with The Data
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Temperature Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Temperature', fontsize= 18)
plt.plot(train['meantemp'], linewidth= 3)
plt.plot(test['meantemp'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])
